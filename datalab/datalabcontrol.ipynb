# %% [markdown]
# # Datalab
#
# Author: Lars Grygosch
# Year: 2024
# Associations: IBG-2 Forschungszentrum Juelich; FAIRAgro TA1 - Use Case 5
#
#
# ### Description
#
# This Notebook is trying to give an Overview of Data which is selected from the IBG-2 Field Phenotyping Group as Candidates for the Benchmark-Datasets or deserve some visibility. It should result in an comprehensive documentation of the status of current available data with the intend
# -   to identify problems and hurdles by experience,
# -   establish new or improve current processes and workflows along the whole data life cycle,
# -   increase visibility of data.
#
# Each Section Starts with a representation of the Datasets in question.

# %% [markdown]
# ## HyData: HyPlant FLUO at-sensor radiance data packages and FLOX measurements for SIF retrival method development from selected campaigns of 2018-2023
#
# Author: Buffat, Jim; Rascher, Uwe; Rademske, Patrick; Siegmann, Bastian; Junker-Frohn, Laura; Emin, Dzhaner
#
# Bibtex:
#
#     @data{JUELICH-DATA/QKJKPW_2024,
#     author = {Buffat, Jim and Rascher, Uwe and Rademske, Patrick and Siegmann, Bastian and Junker-Frohn, Laura Verena and Emin, Dzhaner},
#     publisher = {Juelich DATA},
#     title = {{HyData: HyPlant FLUO at-sensor radiance data packages and FLOX measurements for SIF retrieval method development from selected campaigns of the years 2018 - 2023}},
#     year = {2024},
#     version = {DRAFT VERSION},
#     doi = {10.26165/JUELICH-DATA/QKJKPW},
#     url = {https://doi.org/10.26165/JUELICH-DATA/QKJKPW}
#     }
#
# DOI: https://doi.org/10.26165/JUELICH-DATA/QKJKPW
# Version 1.0
#
# Repository: https://data.fz-juelich.de
# Repository Information: "Jülich DATA is the central institutional repository for research data of Forschungszentrum Jülich. It serves as a platform for all research data generated at Forschungszentrum Jülich or created in this context. Registered within [re3data.org](http://doi.org/10.17616/R31NJMYC)"
#
# Comments:
# - The actual data lies at the storage: https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/
# - HyPlant Information: https://www.fz-juelich.de/en/ibg/ibg-2/expertise/technology-process-development/hyplant
#
# ### Metadata
#
# #### Investigation - MIAPPE
# Investigation unique ID: 10.26165/JUELICH-DATA/QKJKPW
# Investigation title: "HyData: HyPlant FLUO at-sensor radiance data packages and FLOX measurements for SIF retrieval method development from selected campaigns of the years 2018 - 2023"
# Investigation description: "This dataset consists of HyPlant FLUO at-sensor radiance measurements from different campaigns in the years 2018 - 2023, FLOX measurements corresponding to several campaigns and matching SFMNN and SFM SIF products."
# Submission date: 2024-05-24
# Public release date: 2024-07-05
# License: CC-BY 4.0 - "Attribution"
# MIAPPE version: 1.1
# Associated publication: DOI: 10.22541/essoar.172411876.66031071/v1
# > Cite as: Jim Buffat, Miguel Pato, Kevin Alonso, et al. A Multi-Layer Perceptron Approach for SIF Retrieval in the O2-A Absorption band from Hyperspectral Imagery of the HyPlant Airborne Sensor System. ESS Open Archive . August 20, 2024.
#
# #### Keywords
# Solar-Induced Fluorescence
# Spectral Fitting Methods
# Deep Learning
# Neural Netwoks
# Hyperspectral Sensors
# Remote Sesning
# SIF Retrieval
#
#
# #### Results (MIAPPE Extension)
#
# Results are within this directory sorted into products!!! As a Product it is most likely processed from a raw data file. The Processing steps are documented within provenance....
#
#
#
#
# ### Dataset Overview
#
# The Dataset contains 3748 Files of approximatly 1.65 TB in total. It consists of radiance
#
# Total Files: 3748
# Total Size: 1817975698561 bytes (1.65 T)
# Format Distribution: {'txt': 295, 'opt': 287, 'dat': 866, 'hdr': 1347, 'atm': 7, 'csv': 14, 'dbf': 15, 'prj': 15, 'qpj': 13, 'shp': 16, 'shx': 15, 'jpg': 1, 'cpg': 3, 'xlsx': 1, 'bil': 460, 'bsq': 393}
# Label Distribution: {}
#
# ### Purpose and Methods
#
# The primary goal of this dataset is to derive SIF to estimate the photosynthetic activity of plant canopies over large areas. SIF retrieval involves separating fluorescence signals from reflectance and atmospheric interference, a complex process requiring advanced radiative transfer models and machine learning methods. The study introduces the **Spectral Fitting Method Neural Network (SFMNN)** as a novel approach that self-supervises the fluorescence retrieval from raw radiance measurements, yielding improved results in complex terrains.
#
# ### Labeling and Hierarchical Structure
#
# The data was labeled based on the directory structure, with categories like **metadata** (e.g., README files), **data** (core measurement files), and **processed results** (analyzed or aggregated data files).
#
# ### Key Data Points
#
# - **HyPlant Campaigns**: The dataset includes measurements from multiple campaigns across different locations, altitudes, and conditions. These campaigns cover various vegetation types and seasonal variations, giving insights into SIF retrieval performance under different environmental settings.
# - **Ground Truthing**: To validate the SIF data, some campaigns included in-situ **FLOX system** measurements. These ground-based radiance measurements serve as benchmarks to assess the accuracy of airborne SIF retrieval.
#
# ### Applications and Potential Insights
#
# This dataset provides a comprehensive view of **plant photosynthetic dynamics**, **diurnal changes**, and **spatial variations** in SIF. Applications range from **precision agriculture** and **environmental monitoring** to **validation of satellite sensors** like ESA’s upcoming FLEX mission.
#
#
# ### Campaigns
#
#
# ### Location Codes
#
# CKA:  Campus-Klein Altendorf, DE
# SEL:  Selhausen, DE
# WST:  Braccagni, IT
# NRS:  Braccagni, IT
# TR32: Juelich, DE
# HOE:  Hoelster, CH
# JIM:  Lindenberger Wald, DE
# INN:  (near) Buergewald, DE
# GLO:  Mollerusse, ES
#
#
#
#
#
# | Year_Location_Altitude | FLOX Data | Notes |
# |-|-|-|
# | 2018_SEL_| | |
# | 2019_WST_1500 | |  |
# | 2019_NRS_1500 | |  |
# | 2019_SEL_0600 | |  |
# | 2019_TR32_1800  | |  |
# | 2020_CKA_0350 | |  |
# | 2020_CKA_0600 | |  |
# | 2021_CKA_0350 | |  |
# | 2021_HOE_0600 | |  |
# | 2021_GLO_1150 | |  |
# | 2022_HOE_0600 | |  |
# | 2022_CKA_0350 | |  |
# | 2022_INN_0600 | |  |
# | 2022_SEL_0600 | |  |
# | 2023_JIM_0600 | |  |
# ### Key Observations
#
# - **High Temporal and Spatial Resolution**: This dataset provides a comprehensive view across multiple years and locations, with each campaign contributing to a unique understanding of solar-induced fluorescence (SIF) and vegetation monitoring.
# - **Specific Assays**:
#   - **FLUO**: Data was regularly collected in early morning or midday conditions (e.g., 0600, 1500), capturing diurnal cycles.
#   - **SFMNN vs. SFM**: The data, particularly from highly variable terrains (like 2023_JIM_0600 in Sopron, HU), supports comparing SFM and SFMNN retrieval methods.
# - **Ground Validation**: FLOX data collection was prominent in early years and specific locations (SEL, WST, CKA), offering critical ground truth measurements that enhance reliability and potential for model validation.
#
# This enriched summary outlines each year’s data focus, capturing varied altitudes, topographic conditions, and in-situ validation that make the dataset versatile for both vegetation and atmospheric studies.

# %%
"""requirements.txt

requests
beautifulsoup4
"""

import requests
from bs4 import BeautifulSoup
import re




# Open Url and scrape for information

def scrape_html_index(url):
    """Collects data from datapub.fz-juelich"""
    response = requests.get(url)

    # if connection failes return an empty list
    if response.status_code != 200:
        print("Failed to connect")
        return {url : []}
    
    # Find all rows in the index table (apart from header and parent link)
    soup = BeautifulSoup(response.text, 'html.parser')
    rows = soup.find("table").find_all("tr")[3:]

    # items are collected here
    items = {url : []}

    for row in rows:
        # Template for collecting data
        col_data = {"name":None, 
                    "type":None, 
                    "format":None,
                    "last_mod":None, 
                    "size":None,
                    "size_unit_split":None, 
                    "desc":None}

        cols = row.find_all('td')[1:]
        # better check for the correct amount of cols
        if len(cols) == 4:
            # getting the name
            name = cols[0].find("a").get("href")
            col_data["name"] = name

            # getting the description
            if cols[3].text != "\xa0":
                col_data["desc"] = cols[3].text

            # Last modification
            col_data["last_mod"] = cols[1].text

            # Dealing with files (identifiable trough name)
            if not name.endswith("/"):
                col_data["type"] = "file"
                col_data["format"] = name.split(".")[-1]

                # getting the files size
                size = cols[2].text
                col_data["size"] = size

                match = re.match(r'([0-9]*\.?[0-9]+)([KMGTP]?)', size)

                if match:
                    number = float(match.group(1))
                    unit = match.group(2) if match.group(2) else None
                    col_data["size_unit_split"] = (number, unit)
                else:
                    col_data["size_unit_split"] = (None, "B")


            else:
                col_data["type"] = "folder"

            items[url].append(col_data)
    return items

def explore_folders(url):
    """Recursively explore folders and collect information."""
    folder_structure = {}

    def recursive_search(current_url):
        # collect info from html
        items = scrape_html_index(current_url) 
        folder_structure.update(items)

        for item in items[current_url]:
            # if folder, start recursion
            if item['type'] == 'folder':
                new_url = current_url + item['name']
                recursive_search(new_url)

    recursive_search(url)
    return folder_structure

def gather_file_info(url, label_func = None):
    """Refines the collected information for the files
    
    label_func is implemented for now to control somehow manually labeling of the data files
    """

    filedata = []
    for path, data in folder_structure.items():
        for d in data:
            if d["type"] == "file":
                filedata.append({"url" : path + d["name"],
                                 "folder" : path, 
                                 "name" : d["name"], 
                                 "format" : d["format"], 
                                 "last_mod" : d["last_mod"], 
                                 "size_unit_split" : d["size_unit_split"],
                                 "label" : None})
    return filedata

# Utility Functions

def convert_to_bytes(value, unit):
    """Converts a value with a given unit to bytes."""
    units = {'B': 1, 'K': 1024, 'M': 1024 ** 2, 'G': 1024 ** 3, 'T': 1024 ** 4, 'P': 1024 ** 5, 'E': 1024 ** 6}
    return int(value * units.get(unit.upper(), 1))

def from_bytes(value):
    """Converts a byte value to the highest appropriate unit for readability."""
    units = ['B', 'K', 'M', 'G', 'T', 'P', 'E']
    for unit in units:
        if value < 1024:
            return round(value, 2), unit
        value /= 1024
    return round(value, 2), 'E'

def total_size_in_bytes(data):
    """Calculates the total size in bytes from a list of size unit pairs."""
    return sum(convert_to_bytes(*d["size_unit_split"]) for d in data)

def gather_file_statistics(data):
    """Collects summary statistics about files, including counts, size, format distribution, and label distribution."""
    total_files = len(data)
    total_size = total_size_in_bytes(data)
    format_dist = {}
    label_dist = {}

    for d in data:
        # Format distribution
        fmt = d["format"]
        format_dist[fmt] = format_dist.get(fmt, 0) + 1
        
        # Label distribution (assuming 'label' field is used)
        label = d.get("label")
        if label:
            label_dist[label] = label_dist.get(label, 0) + 1

    return {
        'total_files': total_files,
        'total_size_bytes': total_size,
        'total_size_readable': from_bytes(total_size),
        'format_distribution': format_dist,
        'label_distribution': label_dist
    }

# Example usage
url = 'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/'
folder_structure = explore_folders(url)

for data in folder_structure.values():
    for d in data:
        if d["type"] == "file":
            print(*d["size_unit_split"])

# filedata = gather_file_info(folder_structure)
# get_info(filedata)


# Manual Labeling of folders
# Out:
# 4.2 K
# 1.8 K
# 3.7 K
# 1.1 K
# 1.9 K
# 434.0 M
# 885.0 None
# 8.2 G
# None B
# 1.2 M
# 1.9 K
# 517.0 M
# 886.0 None
# 8.8 G
# None B
# 1.3 M
# 1.9 K
# 519.0 M
# 886.0 None
# 8.9 G
# None B
# 1.3 M
# 1.9 K
# 464.0 M
# 885.0 None
# 8.1 G
# None B
# 1.2 M
# 1.9 K
# 481.0 M
# 886.0 None
# 8.6 G
# None B
# 1.3 M
# 1.9 K
# 411.0 M
# 885.0 None
# 7.6 G
# None B
# 1.1 M
# 1.9 K
# 439.0 M
# 885.0 None
# 8.0 G
# None B
# 1.2 M
# 1.9 K
# 483.0 M
# 886.0 None
# 8.6 G
# None B
# 1.2 M
# 1.9 K
# 473.0 M
# 886.0 None
# 8.5 G
# None B
# 1.2 M
# 1.9 K
# 445.0 M
# 886.0 None
# 8.3 G
# None B
# 1.2 M
# 1.9 K
# 523.0 M
# 886.0 None
# 9.0 G
# None B
# 1.3 M
# 1.9 K
# 525.0 M
# 886.0 None
# 9.0 G
# None B
# 1.3 M
# 1.9 K
# 538.0 M
# 886.0 None
# 9.2 G
# None B
# 1.3 M
# 1.9 K
# 385.0 M
# 885.0 None
# 7.7 G
# None B
# 1.1 M
# 1.9 K
# 440.0 M
# 885.0 None
# 8.0 G
# None B
# 1.2 M
# 1.9 K
# 454.0 M
# 886.0 None
# 8.3 G
# None B
# 1.2 M
# 1.9 K
# 532.0 M
# 886.0 None
# 8.8 G
# None B
# 1.3 M
# 1.9 K
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re

def fetch_html_content(url):
    """Fetches HTML content from a URL and returns the response text, or None if the connection fails."""
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to connect to {url}")
        return None
    return response.text

def parse_table_rows(html_content):
    """Parses rows from an HTML table, skipping headers and parent links, and returns a list of row elements."""
    soup = BeautifulSoup(html_content, 'html.parser')
    return soup.find("table").find_all("tr")[3:]

def extract_file_info(row):
    """Extracts file or folder information from a row and returns a dictionary of details."""
    columns = row.find_all('td')[1:]
    if len(columns) != 4:
        return None

    item_info = {
        "name": columns[0].find("a").get("href"),
        "type": "folder" if columns[0].find("a").get("href").endswith("/") else "file",
        "last_modified": columns[1].text,
        "size": columns[2].text,
        "description": columns[3].text if columns[3].text.strip() != "\xa0" else None,
        "format": None,
        "size_info": None
    }

    if item_info["type"] == "file":
        item_info["format"] = item_info["name"].split(".")[-1]
        size_match = re.match(r'([0-9]*\.?[0-9]+)([KMGTP]?)', item_info["size"])
        if size_match:
            item_info["size_info"] = (float(size_match.group(1)), size_match.group(2) if size_match.group(2) else 'B')
    return item_info

def collect_index_data(url):
    """Collects file and folder data from a specified URL."""
    html_content = fetch_html_content(url)
    if not html_content:
        return {url: []}

    rows = parse_table_rows(html_content)
    collected_items = {url: []}
    
    for row in rows:
        item_info = extract_file_info(row)
        if item_info:
            collected_items[url].append(item_info)
    
    return collected_items

def explore_directory_tree(root_url):
    """Recursively explores folders, collecting information on files and subfolders."""
    directory_data = {}

    def recursive_collect(current_url):
        items = collect_index_data(current_url)
        directory_data.update(items)
        
        for item in items.get(current_url, []):
            if item['type'] == 'folder':
                recursive_collect(current_url + item['name'])

    recursive_collect(root_url)
    return directory_data

def consolidate_file_data(directory_data, label_function=None):
    """Consolidates file-specific data, optionally applying a label function."""
    file_details = []
    
    for folder_url, items in directory_data.items():
        for item in items:
            if item["type"] == "file":
                file_info = {
                    "url": folder_url + item["name"],
                    "folder": folder_url,
                    "name": item["name"],
                    "format": item["format"],
                    "last_modified": item["last_modified"],
                    "size_info": item["size_info"],
                    "label": label_function(item) if label_function else None
                }
                file_details.append(file_info)
    
    return file_details
# Out:
# README.txt, (4.2, 'K')
# README_DEMs.txt, (1.8, 'K')
# README_FLOX.txt, (3.7, 'K')
# README_radiance.txt, (1.1, 'K')
# 20180626-SEL-1522-600-L6-N-FLUO.opt, (1.9, 'K')
# 20180626-SEL-1522-600-L6-N-FLUO_GLT.dat, (434.0, 'M')
# 20180626-SEL-1522-600-L6-N-FLUO_GLT.hdr, (885.0, None)
# 20180626-SEL-1522-600-L6-N-FLUO_radiance.dat, (8.2, 'G')
# 20180626-SEL-1522-600-L6-N-FLUO_radiance.hdr, (None, 'byte')
# 20180626-SEL-1522-600-L6-N-FLUO_syncedNav.txt, (1.2, 'M')
# 20180626-SEL-1526-600-L5-S-FLUO.opt, (1.9, 'K')
# 20180626-SEL-1526-600-L5-S-FLUO_GLT.dat, (517.0, 'M')
# 20180626-SEL-1526-600-L5-S-FLUO_GLT.hdr, (886.0, None)
# 20180626-SEL-1526-600-L5-S-FLUO_radiance.dat, (8.8, 'G')
# 20180626-SEL-1526-600-L5-S-FLUO_radiance.hdr, (None, 'byte')
# 20180626-SEL-1526-600-L5-S-FLUO_syncedNav.txt, (1.3, 'M')
# 20180626-SEL-1530-600-L4-N-FLUO.opt, (1.9, 'K')
# 20180626-SEL-1530-600-L4-N-FLUO_GLT.dat, (519.0, 'M')
# 20180626-SEL-1530-600-L4-N-FLUO_GLT.hdr, (886.0, None)
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re

class Dataset_DataPub:
    def __init__(self, root_url):
        self.root_url = root_url
        self.folder_structure = {}
        self.file_data = []

    def _fetch_html(self, url):
        """Fetch HTML content from a URL."""
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to connect to {url}")
            return None
        return BeautifulSoup(response.text, 'html.parser')

    def _parse_row(self, row):
        """Extracts data from a table row into a structured dictionary."""
        columns = row.find_all('td')[1:]
        if len(columns) != 4:
            return None

        col_data = {
            "name": columns[0].find("a").get("href"),
            "type": "folder" if columns[0].find("a").get("href").endswith("/") else "file",
            "last_mod": columns[1].text,
            "size": columns[2].text,
            "desc": columns[3].text if columns[3].text.strip() != "\xa0" else None,
            "format": None,
            "size_unit_split": None,
        }

        if col_data["type"] == "file":
            col_data["format"] = col_data["name"].split(".")[-1]
            size_match = re.match(r'([0-9]*\.?[0-9]+)([KMGTP]?)', col_data["size"])
            if size_match:
                col_data["size_unit_split"] = (float(size_match.group(1)), size_match.group(2) if size_match.group(2) else 'B')
        
        return col_data

    def scrape_html_index(self, url):
        """Scrape and collect index data from a URL."""
        soup = self._fetch_html(url)
        if not soup:
            return {url: []}

        rows = soup.find("table").find_all("tr")[3:]
        items = {url: []}
        
        for row in rows:
            row_data = self._parse_row(row)
            if row_data:
                items[url].append(row_data)
        
        return items

    def explore_folders(self):
        """Recursively explore folders and build the folder structure."""
        def recursive_collect(current_url):
            items = self.scrape_html_index(current_url)
            self.folder_structure.update(items)
            
            for item in items.get(current_url, []):
                if item['type'] == 'folder':
                    recursive_collect(current_url + item['name'])
        
        recursive_collect(self.root_url)

    def gather_file_info(self, label_func=None):
        """Refine collected file information with optional custom labeling."""
        self.file_data = []
        for path, data in self.folder_structure.items():
            for item in data:
                if item["type"] == "file":
                    file_info = {
                        "url": path + item["name"],
                        "folder": path,
                        "name": item["name"],
                        "format": item["format"],
                        "last_mod": item["last_mod"],
                        "size_unit_split": item["size_unit_split"],
                        "label": label_func(item) if label_func else None
                    }
                    self.file_data.append(file_info)

    @staticmethod
    def convert_to_bytes(value, unit):
        """Convert a value with a given unit to bytes."""
        units = {'B': 1, 'K': 1024, 'M': 1024 ** 2, 'G': 1024 ** 3, 'T': 1024 ** 4, 'P': 1024 ** 5, 'E': 1024 ** 6}
        return int(value * units.get(unit.upper(), 1))

    @staticmethod
    def from_bytes(value):
        """Convert a byte value to the highest appropriate unit for readability."""
        units = ['B', 'K', 'M', 'G', 'T', 'P', 'E']
        for unit in units:
            if value < 1024:
                return round(value, 2), unit
            value /= 1024
        return round(value, 2), unit

    def total_size_in_bytes(self):
        """Calculate total size in bytes from file data."""
        return sum(self.convert_to_bytes(*file["size_unit_split"]) for file in self.file_data if file["size_unit_split"])

    def gather_file_statistics(self):
        """Collect summary statistics including file count, size, format distribution, and label distribution."""
        total_files = len(self.file_data)
        total_size = self.total_size_in_bytes()
        format_dist = {}
        label_dist = {}

        for file in self.file_data:
            # Format distribution
            format_dist[file["format"]] = format_dist.get(file["format"], 0) + 1
            
            # Label distribution
            label = file["label"]
            if label:
                label_dist[label] = label_dist.get(label, 0) + 1

        return {
            'total_files': total_files,
            'total_size_bytes': total_size,
            'total_size_readable': self.from_bytes(total_size),
            'format_distribution': format_dist,
            'label_distribution': label_dist
        }


#### Test
url = 'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/'

# Create an instance of Dataset_DataPub with the root URL
dataset = Dataset_DataPub(url)

# Explore the folders and collect data
dataset.explore_folders()


# Manually Design for label the data files
def custom_labeling_function(file_data):
    pass
    # """Assigns hierarchical labels based on file path and naming conventions."""
    # file_name = file_data.get("name", "").lower()  # Use .get() to avoid KeyError if key is missing
    # folder_path = file_data.get("folder", "").lower()  # Use .get() to avoid KeyError if key is missing
    # path_segments = folder_path.split('/') if folder_path else []  # Ensure path_segments is empty if folder_path is missing

    # # Rule 1: Metadata labeling
    # if "readme" in file_name or file_name.endswith(".txt") :
    #     return ("META", "metadata")

    # # Rule 2: Files in '01_data' are labeled as 'data'
    # elif "01_data" in folder_path:
    #     # Check for assay type within path or filename
    #     if "fluo" in folder_path or "fluo" in file_name:
    #         return ("ASSAY", "FLUO")
    #     elif "dem" in folder_path or "dem" in file_name:
    #         return ("ASSAY", "DEM")
    #     elif "flox" in folder_path or "flox" in file_name:
    #         return ("ASSAY", "FLOX")
    #     else:
    #         return ("ASSAY", "unclassified_data")
    
    # # Rule 3: Files in '02_products' are labeled as processed results
    # elif "02_products" in folder_path:
    #     if "sfm" in folder_path or "sfm" in file_name:
    #         return ("STUDY", "SFM")
    #     elif "sfmnn" in folder_path or "sfmnn" in file_name:
    #         return ("STUDY", "SFMNN")
    #     else:
    #         return ("STUDY", "unclassified_product")
    
    # # Rule 4: If metadata is a subcategory of data
    # elif "data" in folder_path and "meta" in file_name:
    #     return ("ASSAY", "META")
    
    # # Rule 5: Additional general metadata collection
    # elif "product" in folder_path and "meta" in file_name:
    #     return ("STUDY", "META")
    
    # # Default label for any uncategorized files
    # return ("META", "general")


# Gather detailed file information
# Optionally, you can pass a custom labeling function. For now, we’ll set it to None.
dataset.gather_file_info(label_func=custom_labeling_function)

# Step 3: Retrieve and display file statistics
file_statistics = dataset.gather_file_statistics()
print("File Statistics:")
print(f"Total Files: {file_statistics['total_files']}")
print(f"Total Size: {file_statistics['total_size_bytes']} bytes ({file_statistics['total_size_readable'][0]} {file_statistics['total_size_readable'][1]})")
print("Format Distribution:", file_statistics['format_distribution'])
print("Label Distribution:", file_statistics['label_distribution'])

print("\nLabeled File Data with Hierarchical Labels:")
for file in dataset.file_data:
    print(file)
# Out:
# File Statistics:
# Total Files: 3748
# Total Size: 1817975698561 bytes (1.65 T)
# Format Distribution: {'txt': 295, 'opt': 287, 'dat': 866, 'hdr': 1347, 'atm': 7, 'csv': 14, 'dbf': 15, 'prj': 15, 'qpj': 13, 'shp': 16, 'shx': 15, 'jpg': 1, 'cpg': 3, 'xlsx': 1, 'bil': 460, 'bsq': 393}
# Label Distribution: {}
#
# Labeled File Data with Hierarchical Labels:
# {'url': 'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/README.txt', 'folder': 'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/', 'name': 'README.txt', 'format': 'txt', 'last_mod': '2024-06-28 06:26  ', 'size_unit_split': (4.2, 'K'), 'label': None}
# {'url': 'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/01_data/README_DEMs.txt', 'folder': 'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/01_data/', 'name': 'README_DEMs.txt', 'format': 'txt', 'last_mod': '2024-06-28 06:19  ', 'size_unit_split': (1.8, 'K'), 'label': None}
# ...

# %% [markdown]
# # Bastian
#
# DOI: http://dx.doi.org/10.5447/IPK/2019/21
