# %% [markdown]
# # HyPlant
#
# ## Benchmark Overview
#
# LOREM IPSUM

# %% [markdown]
# # HyPlant Dataset
#
# ## Responsibility
#
#     Buffat, Jim
#
# ## People
#
#     Buffat, Jim (IBG-2)
#     Rascher, Uwe (IBG-2)
#     Rademske, Patrick (IBG-2)
#     Siegmann, Bastian (IBG-2)
#     Junker-Frohn, Laura (IBG-2)
#     Emin, Dzhaner (IABG)
#
# ## Time
#
#     2018-2023
#
# ## Location
#
#     CKA:  Campus-Klein Altendorf, DE
#     SEL:  Selhausen, DE
#     WST:  Braccagni, IT
#     NRS:  Braccagni, IT
#     TR32: Juelich, DE
#     HOE:  Hoelstein, CH
#     JIM:  Lindenberger Wald, DE
#     INN:  (near) Buergewald, DE
#     GLO:  Mollerussa, ES
#
#
# ## Data Location
#
#     https://doi.org/10.26165/JUELICH-DATA/QKJKPW
#
#
# ## Dataset Name
#
#     HyData: HyPlant FLUO at-sensor radiance data packages and FLOX measurements for SIF retrieval method development from selected campaigns of the years 2018 - 2023
#
# ## Description
#
#     This dataset consists of HyPlant FLUO at-sensor radiance measurements from different campaigns in the years 2018 - 2023, FLOX measurements corresponding to several campaigns and matching SFMNN and SFM SIF products.
#
# ## Dataset Text [EDIT]
#
# The Datase
#
#
# Total Files: 3748
# Total Size: 1817975698561 bytes (1.65 T)
# Format Distribution: {'txt': 295, 'opt': 287, 'dat': 866, 'hdr': 1347, 'atm': 7, 'csv': 14, 'dbf': 15, 'prj': 15, 'qpj': 13, 'shp': 16, 'shx': 15, 'jpg': 1, 'cpg': 3, 'xlsx': 1, 'bil': 460, 'bsq': 393}
#
#
# ## Keywords
#
#     Solar-Induced Fluorescence
#     Spectral Fitting Methods
#     Deep Learning
#     Neural Netwoks
#     Hyperspectral Sensors
#     Remote Sesning
#     SIF Retrieval
#
# ## Subject
#
#     Agricultural Sciences
#     Computer and Information Science
#     Earth and Environmental Sciences
#
# ## Dataset Size
#
#     1.65 TB (3748 files)
#
# ## Dataset Publication
#
#     isPublished: True
#     identifier: doi:10.26165/JUELICH-DATA/QKJKPW
#     url: https://doi.org/10.26165/JUELICH-DATA/QKJKPW
#     PublicationDate: 2024-07-05
#     DepositionDate: 2024-05-24
#     Accessibilty: open
#
# ## Version
#
#     1.0
#
# ## License
#
#     CC-BY 4.0 - "Attribution"
#
#
# ## Paper
#
#     - hasRelatedPaper: True
#     - paperIdentifief: doi:10.22541/essoar.172411876.66031071/v1
#     - paperURL: https://doi.org/10.22541/essoar.172411876.66031071/v1
#
# Cite as: Jim Buffat, Miguel Pato, Kevin Alonso, et al. A Multi-Layer Perceptron Approach for SIF Retrieval in the O2-A Absorption band from Hyperspectral Imagery of the HyPlant Airborne Sensor System. ESS Open Archive . August 20, 2024.
#
#
# ## Comments
#
# Candidate has interdisciplinary character between agricultural science, environmental science and computer and information science. The Dataset is subdivided into the
#
#
# ## DataPub Structure
#
# | FLUO: Year_Location_Altitude | FLOX Data | SFM Products | SFMNN Products | Comments(*) |
# |-|-|-|-|-|
# | 2018_SEL_600 | X | X | X | Part of FLEXSense2018 https://doi.org/10.57780/esa-ae7953d |
# | 2019_WST_1500 | X | X | X | Part of FLEXSense 2019 https://doi.org/10.57780/esa-84e5bf5 |
# | 2019_NRS_1500 | X | - | X | Part of FLEXSense 2019 https://doi.org/10.57780/esa-84e5bf5 |
# | 2019_SEL_0600 | - | - | - | Part of FLEXSense 2019 https://doi.org/10.57780/esa-84e5bf5 |
# | 2019_TR32_1800  | - | X | X | Part of FLEXSense 2019 https://doi.org/10.57780/esa-84e5bf5 |
# | 2020_CKA_0350 | X | X | X | |
# | 2020_CKA_0600 | X | X | X | |
# | 2021_CKA_0350 | X | X | X | |
# | 2021_HOE_0600 | - | - | - | |
# | 2021_GLO_1150 | X | - | X | |
# | 2022_HOE_0600 | - | - | - | |
# | 2022_CKA_0350 | X | X | X | |
# | 2022_INN_0600 | - | X | X | |
# | 2022_SEL_0600 | - | - | - | |
# | 2023_JIM_0600 | - | - | X | |
#
#
# (*) Comments added by Data Reviewer
#
# ## ARC-Structure
#     |- *Metadata Investigation*
#     |- Studies/
#         |- *Metadata_Studies*
#         |- 2018_SEL/
#         |- 2019_WST/
#         |- 2019_NRS/
#         |- 2019_SEL/
#         |- 2019_TR32/
#         |- 2020_CKA/
#         |- 2021_CKA/
#         |- 2021_HOE/
#         |- 2021_GLO/
#         |- 2022_HOE/
#         |- 2022_CKA/
#         |- 2022_INN/
#         |- 2022_SEL/
#         |- 2023_JIM/
#     |- Assays/
#         |- *Metadata Assays*
#         |- FLUO/
#             |- 2018_SEL_0600/
#             |- 2019_WST_1500/
#             |- 2019_NRS_1500/
#             |- 2019_SEL_0600/
#             |- 2019_TR32_1800/
#             |- 2020_CKA_0350/
#             |- 2020_CKA_0600/
#             |- 2021_CKA_0350/
#             |- 2021_HOE_0600/
#             |- 2021_GLO_1150/
#             |- 2022_HOE_0600/
#             |- 2022_CKA_0350/
#             |- 2022_INN_0600/
#             |- 2022_SEL_0600/
#             |- 2023_JIM_0600/
#         |- FLOX/
#             |- 2018_SEL/
#             |- 2019_WST_NRS/
#             |- 2020_CKA/
#             |- 2021_CKA/
#             |- 2021_GLO/
#             |- 2022_CKA/
#         |- DEMs/
#             |- 2018_SEL_0600/
#             |- 2019_WST_1500/
#             |- 2019_NRS_1500/
#             |- 2019_SEL_0600/
#             |- 2019_TR32_1800/
#             |- 2020_CKA_0350/
#             |- 2020_CKA_0600/
#             |- 2021_CKA_0350/
#             |- 2021_HOE_0600/
#             |- 2021_GLO_1150/
#             |- 2022_HOE_0600/
#             |- 2022_CKA_0350/
#             |- 2022_INN_0600/
#             |- 2022_SEL_0600/
#             |- 2023_JIM_0600/
#     |- Runs/
#         |- *Metadata Runs*
#         |- SFM/
#             |- 2018_SEL_0600/
#             |- 2019_WST_1500/
#             |- 2019_NRS_1500/
#             |- 2019_SEL_0600/
#             |- 2019_TR32_1800/
#             |- 2020_CKA_0350/
#             |- 2020_CKA_0600/
#             |- 2021_CKA_0350/
#             |- 2021_HOE_0600/
#             |- 2021_GLO_1150/
#             |- 2022_HOE_0600/
#             |- 2022_CKA_0350/
#             |- 2022_INN_0600/
#             |- 2022_SEL_0600/
#             |- 2023_JIM_0600/
#         |- SFMNN/
#             |- 2018_SEL_0600/
#             |- 2019_WST_1500/
#             |- 2019_NRS_1500/
#             |- 2019_SEL_0600/
#             |- 2019_TR32_1800/
#             |- 2020_CKA_0350/
#             |- 2020_CKA_0600/
#             |- 2021_CKA_0350/
#             |- 2021_HOE_0600/
#             |- 2021_GLO_1150/
#             |- 2022_HOE_0600/
#             |- 2022_CKA_0350/
#             |- 2022_INN_0600/
#             |- 2022_SEL_0600/
#             |- 2023_JIM_0600/
#
#     |- Workflows/
#         |- *Metadata Workflows*
#
# ## Issues
#
# - Datapub does not provide easy solution to download material -> Script needs to be added
# - Naming Convention misleading
# - Metadata in txt format
# - Redundant Structuring
# - Large Dataset (3748 Datafiles of total 1.65 T)
# - Heterogeneous File Formats
#
# ## Sensors and Platforms
#
# HyPlant imaging spectrometer consists of two sensor-modules:
#
# - The DUAL module records hyperspectral data in the spectral range from 400-2500nm, which is useful in deriving biochemical and structural plant properties.
#
# - The FLUO module acquires data in the red and near-infrared bands in the spectral range of 670-780nm with a distinctly higher spectral resolution and sampling interval.
#
# Hyperspectral imaging has the benefit of cost-efficient and non-destructive assessment of structural (e.g. leaf area index, biomass) or biochemical (e.g. pigment or water content) vegetation properties.
#
#
#
#
# **FLOX Systems:**
# FLOX systems are used to measure top-of-canopy reflectance and solar-induced fluorescence (SIF) using high-performance spectrometers
#
# The FLOX was developed by the IBG-2: Plant Sciences of the Jülich Research Center and the Remote Sensing of Environmental Dynamics Laboratory of the University Milano-Bicocca. In 2015, two members of the partners founded the new start-up company JB Hyperspectral http://jb-hyperspectral.com/wordpress/. The commercial versions of the FLOX Boxes are distributed by this young start-up company.
# FLOX is measuring the sun-induced chlorophyll fluorescence (SIF) of plant canopies as a measure of plant photosynthetic capacity under natural light conditions. A QEPro spectrometer from Ocean Optics covering the Red/Near Infrared region (650 – 800 nm) measures chlorophyll fluorescence of plant canopies in the wavelength region of the two atmospheric oxygen absorption bands, O2B and O2A (689 nm and 760 nm, respectively), with a high spectral resolution. SIF of plant canopies can be constantly monitored by the comparison of sequential measurements of light reflected and emitted from the plant canopy using a downward fiberoptics and solar irradiance using an upward directed reference fiberoptics. The spectrometers are embedded in a temperature controlled housing to maintain a stable level of dark current of the spectrometers. An accurate automatic optimization of the measurement duration of both channels to prevailing light conditions is applied to maximize the signal-to-noise ratio and minimize acquisition time. Thereby, FLOX can be used to constantly monitor SIF under changing environmental conditions.
#
# The Shoot group at IBG-2 currently operates 5 FLox systems, some of which are used as stationary systems to continuously record solar-induced fluorescence (SIF) and hyperspectral reflectance from selected study sites and which thus produce time-series of vegetation functioning over the season. Other FLOX systems ae integrated in sensor positioning platforms and are operated within various projects to measure SIF and vegetation reflectance across experimental field systems. One FLOX system ist currently being modified in cooperatin with the manufacturer to be mounted on a UAV platform to enable SIF measurements from low flying plattforms.
#
# Additionally, we are operating 2 ROX systems, which are smaller versions consisting of only one spectrometer. The ROX systems measure canopy reflectance but cannot be used to retrieve solar-induced fluorescence. The ROX systems are used as small weight field spectrometers to record canopy and leaf reflectance.
#
# FLOX and ROX can be combined with the leaf-clip FluoWAT, which is a custom made leaf clip to measure leaf-reflecance and transmittance as well as upwelling and down-welling solar induced fluorescence from single leaves in the field.

# %%
# Gatherin information from DataPub

import os
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime


class Dataset_DataPub:
    UNIT_MULTIPLIERS = {
        'B': 1,
        'K': 1024,
        'M': 1024**2,
        'G': 1024**3,
        'T': 1024**4,
        'P': 1024**5
    }

    def __init__(self, root_url, auto_exploration = True):
        """
        General repository handling class for scraping and data collection.
        
        Args:
            root_url (str): Root URL of the repository to scrape.
            auto_exploration (bool): if True autmatically scrape for data
        """
        self.root_url = root_url
        self.file_data = []
        if auto_exploration:
            self.explore_folders()

    def _fetch_html(self, url):
        """Fetch HTML content from a URL."""
        try:
            response = requests.get(url)
            response.raise_for_status()
            return BeautifulSoup(response.text, 'html.parser')
        except requests.RequestException as e:
            print(f"Error fetching URL {url}: {e}")
            return None

    def _parse_row(self, row, base_url):
        """
        Extracts data from a table row and adds it to file_data.

        Args:
            row (Tag): A BeautifulSoup tag representing a table row.
            base_url (str): The base URL of the current directory.
        """
        columns = row.find_all('td')[1:]
        if len(columns) != 4:
            return None

        href = columns[0].find("a").get("href")
        item_type = "folder" if href.endswith("/") else "file"

        if item_type == "file":
            size_match = re.match(r'([0-9]*\.?[0-9]+)([KMGTP]?)', columns[2].text.strip())
            size, unit = (float(size_match.group(1)), size_match.group(2) or 'B') if size_match else (0, 'B')

            # Convert size to bytes
            size_in_bytes = size * self.UNIT_MULTIPLIERS.get(unit.upper(), 1)

            # Extract file format, file name, and folder
            file_url = os.path.join(base_url, href)
            file_name = href.split("/")[-1]
            file_format = file_name.split(".")[-1] if "." in file_name else None
            folder = "/".join(file_url.split("/")[:-1])

            # Add extracted information to file_data
            self.file_data.append({
                "url": file_url,
                "last_mod": columns[1].text.strip(),
                "size": size,
                "unit": unit,
                "size_in_bytes": size_in_bytes,
                "desc": columns[3].text.strip() if columns[3].text.strip() != "\xa0" else None,
                "file_name": file_name,
                "file_format": file_format,
                 "folder" : "/".join(file_url.split("/")[len(self.root_url.split("/"))-1: -1])  # Relative folder path
            })

        return href if item_type == "folder" else None

    def explore_folders(self, current_url=None):
        """
        Recursively explore folders and collect file data.

        Args:
            current_url (str): The current URL being explored. Defaults to root_url.
        """
        if current_url is None:
            current_url = self.root_url

        soup = self._fetch_html(current_url)
        if not soup:
            return

        rows = soup.find("table").find_all("tr")[3:]  # Skip header rows
        for row in rows:
            href = self._parse_row(row, current_url)
            if href:  # If it's a folder, recurse
                self.explore_folders(os.path.join(current_url, href))

    def to_dataframe(self):
        """Convert collected file data to a pandas DataFrame."""
        if not self.file_data:
            print("No file data to convert.")
            return pd.DataFrame()
        return pd.DataFrame(self.file_data)

    def save_to_csv(self, name, path = "data"):
        """
        Save the data to a CSV file with a name generated based on the current date and time.

        Args:
            path (str): The directory to save the CSV file.
            name (str): The base name of the file.
        """
        if not os.path.exists(path):
            os.mkdir(path)
        df = self.to_dataframe()
        if df.empty:
            print("No data to save.")
            return

        # Generate the timestamp
        timestamp = datetime.now().strftime("%Y%m%d%H%M")

        # Create the full file name
        csv_file = os.path.join(path, f"{name}_{timestamp}.csv")

        # Save the DataFrame to a CSV file
        df.to_csv(csv_file, index=False)
        print(f"Data saved to {csv_file}")





# url = 'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/'


# dataset = Dataset_DataPub(url)
# dataset.save_to_csv("HyPlant")
# Out:
# Data saved to data\HyPlant_202412041510.csv

# %%
import pandas as pd
import json

class DictPath(dict):
    """
    A dictionary subclass with extended functionality for nested operations.
    """

    def get_nested_value(self, path, separator="/"):
        """
        Retrieve a value from the dictionary using a path-like string.

        Args:
            path (str): The path to the value, e.g., "a/1".
            separator (str): The separator used in the path, default is "/".

        Returns:
            any: The value found at the path, or None if the path is invalid.
        """
        keys = path.split(separator)
        current = self

        try:
            for key in keys:
                current = current[key]
            return current
        except (KeyError, TypeError):
            return None

    def fetch_all_values(self, parent_path="", separator="/"):
        """
        Recursively fetch all values in the dictionary and return their paths and values.

        Args:
            parent_path (str): The current path in the recursion.
            separator (str): The separator used for path construction.

        Returns:
            list: A list of tuples containing the path and the value.
        """
        result = []

        for key, value in self.items():
            current_path = f"{parent_path}{separator}{key}" if parent_path else key

            if isinstance(value, dict):
                # Recurse into the dictionary
                result.extend(DictPath(value).fetch_all_values(current_path, separator))
            else:
                result.append((current_path, value))

        return result

    def write_nested_value(self, path, value, separator="/", append = True):
        """
        Write a value into the dictionary at the specified path.

        Args:
            path (str): The path to the value, e.g., "a/1".
            value (any): The value to set at the specified path.
            separator (str): The separator used in the path, default is "/".
            append : adds a value to a list at the desired path in the structure

        Returns:
            DictPath: The modified dictionary.
        """
        keys = path.split(separator)
        current = self

        for key in keys[:-1]:
            if key not in current or not isinstance(current[key], dict):
                current[key] = DictPath()  # Create nested ExtendedDicts as needed
            current = current[key]
        if append:
            if isinstance(current[keys[-1]], list):
                current[keys[-1]].append(value)
            else:
                current[keys[-1]] = []
        else:   
            current[keys[-1]] = value
        return self

class ARCManager:
    """
    A class to generate and manage an ARC structure from a list of data files (CSV).
    """

    def __init__(self, csv: str, data_structure=None):
        self.data = pd.read_csv(csv)
        self.data_structure = DictPath(data_structure or {})
        self.label_rules = []

    def add_data_structure(self, data_structure: dict):
        """
        Dynamically add or update a custom ARC data structure.

        Args:
            data_structure (dict): The data structure to add or update.
        """
        if not isinstance(data_structure, dict):
            raise ValueError("data_structure must be a dictionary.")
        self.data_structure = DictPath(data_structure)


    def import_arc_structure_txt(self, txtfile: str):
        """
        Import an ARC structure from a text file.

        Args:
            txtfile (str): Path to the text file containing ARC structure paths.

        Example file format:
            studys/study0001
            studys/study0002
            assays/subcategory01/assay01
        """
        if not txtfile.endswith(".txt"):
            raise ValueError("Input file must be a .txt file.")
        
        self.data_structure = DictPath()
        with open(txtfile, "r") as file:
            for line in file.readlines():
                self.data_structure.write_nested_value(line.strip(), [])
        print(f"Imported ARC structure from {txtfile}")


    def add_label_rule(self, func):
        """Adding a rule onto the dataframe, which is adding the arc_ammping entry"""
        self.label_rules.append(func)


    def apply_label_rules(self):
        for rule in self.label_rules:
            self.data = rule(self.data)


    def save_dataframe_to_csv(self, name, path="data"):
        """
        Save the data to a CSV file with a name generated based on the current date and time.

        Args:
            path (str): The directory to save the CSV file.
            name (str): The base name of the file.
        """
        if not os.path.exists(path):
            os.mkdir(path)


        # Generate the timestamp
        timestamp = datetime.now().strftime("%Y%m%d%H%M")

        # Create the full file name
        csv_file = os.path.join(path, f"{name}_{timestamp}_ARCLabeled.csv")

        # Save the DataFrame to a CSV file
        self.data.to_csv(csv_file, index=False)
        print(f"Data saved to {csv_file}")

    def fill_data_structure(self):
        """For this method the labeling needs to be done"""
        for _, row in self.data.iterrows(): 
            try:
                self.data_structure.write_nested_value(row["arc_mapping"], row["url"])
            except:
                print(row["arc_mapping"])
    

    def create_bundles(self):
        pass

    def save_data_structure_to_json(self, filepath):
        """
        Save the current data structure (arc_structure) to a JSON file.

        Args:
            filepath (str): The file path where the JSON will be saved.
        """
        try:
            with open(filepath, 'w', encoding='utf-8') as json_file:
                json.dump(self.data_structure, json_file, ensure_ascii=False, indent=4)
            print(f"Data structure successfully saved to {filepath}")
        except Exception as e:
            print(f"Error saving data structure to JSON: {e}")

    def create_folder_structure(self, path = "../ARC", from_datastructure = True):
        """Helps in generating a folder structure for your ARC"""
        if from_datastructure:
            for folder, file in self.data_structure.fetch_all_values():
                if not os.path.exists(os.path.join(path, folder)):
                    os.makedirs(os.path.join(path, folder))
        else:
            for folder in self.data["arc_mapping"].unique():
                if not os.path.exists(os.path.join(path, folder)):
                    os.makedirs(os.path.join(path, folder))



    
# Creating an ARC on given structure and rules

arc_structure = {
    "meta" :[],
    "studys" : {
        "2018_SEL" : [],
        "2019_WST" : [],
        "2019_NRS" : [],
        "2019_SEL" : [],
        "2019_TR32" : [],
        "2020_CKA" : [],
        "2021_CKA" : [],
        "2021_HOE" : [],
        "2021_GLO" : [],
        "2022_HOE" : [],
        "2022_CKA" : [],
        "2022_INN" : [],
        "2022_SEL" : [],
        "2023_JIM" : []
    },
    "assays" : {
        "meta" : [],
        "FLUO" : {
            "2018_SEL_0600" : [],
            "2019_WST_1500" : [],
            "2019_NRS_1500" : [],
            "2019_SEL_0600" : [],
            "2019_TR32_1800" : [],
            "2020_CKA_0350" : [],
            "2020_CKA_0600" : [],
            "2021_CKA_0350" : [],
            "2021_HOE_0600" : [],
            "2021_GLO_1150" : [],
            "2022_HOE_0600" : [],
            "2022_CKA_0350" : [],
            "2022_INN_0600" : [],
            "2022_SEL_0600" : [],
            "2023_JIM_0600" : []
        },
        "DEMs" : {
            "2018_SEL_0600" : [],
            "2019_WST_1500" : [],
            "2019_NRS_1500" : [],
            "2019_SEL_0600" : [],
            "2019_TR32_1800" : [],
            "2020_CKA_0350" : [],
            "2020_CKA_0600" : [],
            "2021_CKA_0350" : [],
            "2021_HOE_0600" : [],
            "2021_GLO_1150" : [],
            "2022_HOE_0600" : [],
            "2022_CKA_0350" : [],
            "2022_INN_0600" : [],
            "2022_SEL_0600" : [],
            "2023_JIM_0600" : []
        },
        "FLOX" : {
            "2018_SEL" : [],
            "2019_WST_NRS" : [],
            "2020_CKA" : [],
            "2021_CKA" : [],
            "2021_GLO" : [],
            "2022_CKA" : [],
        }
    },
    "workflows" : {
        "FLUO" : [],
        "FLOX" : [],
        "DEMS" : [],
        "SFM" : [],
        "SFMNN" : []
    },
    "runs" : {
        "meta" : [],
        "SFM" : {
            "2018_SEL_0600" : [],
            "2019_WST_1500" : [],
            "2019_TR32_1800" : [],
            "2020_CKA_0350" : [],
            "2020_CKA_0600" : [],
            "2021_CKA_0350" : [],
            "2022_CKA_0350" : [],
            "2022_CKA_0600" : [],
            "2022_INN_0600" : []
        },
        "SFMNN" : {
            "2018_SEL_0600" : [],
            "2019_WST_1500" : [],
            "2019_NRS_1500" : [],
            "2019_TR32_1800" : [],
            "2020_CKA_0350" : [],
            "2020_CKA_0600" : [],
            "2021_CKA_0350" : [],
            "2021_GLO_1150" : [],
            "2022_CKA_0350" : [],
            "2022_INN_0600" : [],
            "2023_JIM_0600" : []
        }
    }
}

def detect_label(dataframe :pd.DataFrame):
    """
    Acts on a DataFrame with the following features:
        - url: Full path of the data file.
        - file_format: File type/format.
        - name: File name.

    The function adds a column 'arc_mapping' with the ARC-compliant label for each row.

    Args:
        dataframe (pd.DataFrame): Input DataFrame containing the file information.

    Returns:
        pd.DataFrame: DataFrame with an additional 'arc_mapping' column.
    """

    def detect_label_inner(path, fformat, ffname):
        """Detects ARC labels based on the rules provided."""
        # Metadata detection
        if not isinstance(path, str):
            return "meta"
        if "01_data" not in path and "02_products" not in path:
            return "meta"

        # Assays detection
        if "01_data" in path:
            if fformat in ["txt", "md"] and "README" in ffname:
                return "assays/meta"
            if "radiance" in path:
                return "assays/FLUO"
            if "FLOX" in path:
                return "assays/FLOX"
            if "DEMs" in path:
                return "assays/DEMs"

        # Runs detection
        if "02_products" in path:
            if fformat in ["txt", "md"] and "README" in ffname:
                return "runs/meta"
            if "SFMNN" in path:
                return "runs/SFMNN"
            if "SFM" in path:
                return "runs/SFM"

        return None

    # def extract_year_location_altitude(filename):
    #     """Extract year, location, and altitude from the file name."""
    #     # match = re.match(r"(\d{4})\d{4}-([A-Z0-9]{3,4})-\d{4}-(\d{3,4})", filename)
    #     match = re.search(r"(\d{4})(\d{2})(\d{2})-([A-Z]{3,4})-\d{4}-(\d{4})", filename)
    #     if match:
    #         year, location, altitude = match.groups()
    #         year, month, day, location, altitude = match.groups()
    #         altitude = altitude.zfill(4)  # Normalize altitude to 4 digits
    #         return f"{year}_{location}_{altitude}"
        # return None

    def extract_year_location_altitude(filename):
        """
        Extract year, location, and altitude from the file name.

        Args:
            filename (str): The file name or path.

        Returns:
            str: A formatted string containing year, location, and altitude,
                or None if no match is found.
        """
        # Match filenames with a pattern like '20190627-TR32-1308-1800'
        match = re.match(r"(\d{4})\d{4}-([A-Z0-9]{3,4})-\d{4}-(\d{3,4})", filename)
        if match:
            year,  location, altitude = match.groups()
            altitude = altitude.zfill(4)  # Normalize altitude to 4 digits
            # Apply specific rules for known anomalies
            return f"{year}_{location}_{altitude}"
        else:
            print(filename)
        return None

    def sort_data(path, fformat, fname):
        """Sort data into ARC-compliant labels."""
        labels = detect_label_inner(path, fformat, fname)

        if not labels:
            return "None"

        sublabel = extract_year_location_altitude(fname)
        if "meta" in labels:
            return labels
        if sublabel:
            return f"{labels}/{sublabel}"
        elif labels == "assays/FLOX":
            if "21-" in path:
                return f"{labels}/2018_SEL"
            elif "22-" in path:
                return f"{labels}/2019_WST_NRS"
            elif "23-" in path:
                return f"{labels}/2020_CKA"
            elif "25-" in path:
                return f"{labels}/2021_CKA"
            elif "26-" in path:
                return f"{labels}/2021_GLO"
            elif "28-" in path:
                return f"{labels}/2022_CKA"
            else:
                return f"assays/meta"
        else:
            return f"meta"

    # Apply the sorting logic to the DataFrame and store results in the 'arc_mapping' column
    dataframe["arc_mapping"] = dataframe.apply(
        lambda row: sort_data(row["folder"], row["file_format"], row["file_name"]), axis=1
    )

    return dataframe
   
    



new_arc = ARCManager(r"C:\Users\l.grygosch\Desktop\FAIRAgro\developement\MIAFPE\benchmark\HyPlant\Scripts\data\arc\HyPlant_202412041752_ARCLabeled.csv")

# Adding Structure
new_arc.add_data_structure(arc_structure)

# new_arc.add_label_rule(detect_label)

# new_arc.apply_label_rules()

new_arc.create_folder_structure()

# new_arc.save_dataframe_to_csv("HyPlant", "data/arc")

# new_arc.fill_data_structure()


# new_arc.save_data_structure_to_json("HyPlant.json")

# %%
import os
import json

def write_files_to_arc(jsonfile, directory = "../ARC", erase_old = True): 
    if erase_old:
        pass
    with open(jsonfile, "r") as f:
        json_data = DictPath(json.load(f))

    for path, fname in json_data.fetch_all_values():
        if not os.path.exists(os.path.join(directory, path)):
            os.makedirs(os.path.join(directory, path))
        name = path.repalce("/", "-") + ".txt"
        try:
            open(name, "r")
        except:
            pass
            

    

write_files_to_arc("HyPlant.json")
# Out:
# {'None': [],
#  'meta': ['https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/README.txt'],
#  'studys': {'2018_SEL': [],
#   '2019_WST': [],
#   '2019_NRS': [],
#   '2019_SEL': [],
#   '2019_TR32': [],
#   '2020_CKA': [],
#   '2021_CKA': [],
#   '2021_HOE': [],
#   '2021_GLO': [],
#   '2022_HOE': [],
#   '2022_CKA': [],
#   '2022_INN': [],
#   '2022_SEL': [],
#   '2023_JIM': []},
#  'assays': {'meta': ['https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/01_data/README_DEMs.txt',
#    'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/01_data/README_FLOX.txt',
#    'https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/01_data/README_radiance.txt'],
#   'FLUO': {'2018_SEL_0600': ['https://datapub.fz-juelich.de/plantsciences/HyData-HyPlant-FLUO/01_data/01_radiance/21-%20FlexSense-%20June%202018/HyPlant/20180626/FLUO/20180626-SEL-1522-600-L6-N-FLUO.opt',
# ...

# %%
# This Script helps convert the information of the csv to MIAFPE format

import pandas as pd

# loading dataframe

data = pd.read_csv(r"data\arc\HyPlant_202412041752_ARCLabeled.csv")



def make_description(row):
    dynamic_comment = None
    # rule set for creating several short comments
    if "assays/FLUO" in row["arc_mapping"]:
        if row["file_name"].endswith("syncedNav.txt"):
            dynamic_comment = "AISA navigation data file"
        elif row["file_name"].endswith("GLT.dat") or row["file_name"].endswith("GLT.hdr"):
            dynamic_comment = "geolayer file to allow orthorectification of the radiance files and SIF estimates."
        elif row["file_name"].endswith("radiance.dat") or row["file_name"].endswith("radiance.hdr"):
            dynamic_comment = "radiometrically calibrated at-sensor radiance in senor geometry acquired by HyPlant FLUO"
        elif row["file_format"] == "opt":
            dynamic_comment = "CaliGeo log file with various variables related to the orthorectification."
    elif "meta" in row["arc_mapping"]:
        dynamic_comment = "Metadata"
    elif "assays/FLOX" in row["arc_mapping"]:
        if row["file_format"] == "shp":
            dynamic_comment = """Shape file - If a single location shape file or a single location in the shape file is provided, 
            it applies to all FLOX data sets under the same parent folder. 
            If multiple shape files  or multiple locations in a single shape file are given, the appropriate FLOX data set can 
            be matched by name or by a column in the shape file."""
        if row["file_format"] == "csv":
            dynamic_comment = "The csv files contain GPS coordinate measurements of low accuracy."
    elif "assays/DEMs" in row["arc_mapping"]:
        dynamic_comment = """digital elevation models (DEMs) and digital terrain models (DTMs) in
                            sensor geometry corresponding to the at-sensor radiances stored in assys/FLUO.
                            The DEMs/DTMs are given in units of meters."""
    elif "runs/SFM" in row["arc_mapping"]:
        dynamic_comment = "SFM product "
        if row["file_name"].endswith("rect.bil") or row["file_name"].endswith("rect.hdr"):
            dynamic_comment += " in world coordinates"
        if row["file_format"] == "hdr":
            dynamic_comment += " The bands of the SFM products are described in the corresponding *.hdr files."
    elif "runs/SFMNN" in row["arc_mapping"]:
        dynamic_comment = """SFMNN product (bsq)"""
        if row["file_name"].endswith("rect.bsq"):
            dynamic_comment += " in world coordinates"

    if not dynamic_comment:
        return f"size:{row["size"]} unit:{row["unit"]}  type:{row["file_format"]}   last modification:{row["last_mod"]}"
    else:
        return f"size:{row["size"]} unit:{row["unit"]}  type:{row["file_format"]}    last modification:{row["last_mod"]}    comment:{dynamic_comment}"

def make_provenance(row):
    """On new DataFrame"""
    # sorting DEMs
    if "DEM" in row["arc_mapping"]:
        if "NRS" in row["arc_mapping"] or "WST" in row["arc_mapping"]:
            return """The base DEM used for acquisitions in Italy was (downloaded on 11.09.2021)

                    Tarquini S., I. Isola, M. Favalli, A. Battistini, G. Dotta (2023). TINITALY, a
                    digital elevation model of Italy with a 10 meters cell size (Version 1.1).
                    Istituto Nazionale di Geofisica e Vulcanologia (INGV).
                    https://doi.org/10.13127/tinitaly/1.1"""
        elif "GLO" in row["arc_mapping"]:
            return """The base DEM used for acquisitions in  Spain (downloaded on 24.04.2022) was the SRTM DEM 
	
                    NASA Shuttle Radar Topography Mission (SRTM)(2013). Shuttle Radar Topography
                    Mission (SRTM) Global. Distributed by OpenTopography.
                    https://doi.org/10.5069/G9445JDF."""
        elif "HOE" in row["arc_mapping"]:
            return """The base DEM used for acquisitions in Switzerland (downloaded on 19.04.2024) was the SRTM DEM 
	
                    NASA Shuttle Radar Topography Mission (SRTM)(2013). Shuttle Radar Topography
                    Mission (SRTM) Global. Distributed by OpenTopography.
                    https://doi.org/10.5069/G9445JDF."""
        else:
            return """The base DTM used for acquisitions in Germany was (downloaded on 15.09.2021)
		
                    DTM Germany DTM 20m, Sonny's LiDAR Digital Terrain Models of Europe,
                    https://sonny.4lima.de"""

# Connect certain files
def find_all_lines_in_DEMs(data):
    sel_data = data[data["arc_mapping"].str.startswith("assays/DEMs")]["file_name"]
    return [x.split("_")[0] for x in sel_data]

bundles = find_all_lines_in_DEMs(data)

# Some of the lines are missing in DEMs unfortunatly
def find_all_missing_lines(data, bundles = bundles):
    missing_bundles = []
    found = False
    sel_data = data[data["arc_mapping"].str.startswith("assays/FLUO")]["file_name"]
    for name in sel_data:
        for bundle in bundles:
            if bundle in name:
                found = True
                break
        if not found:
            if "_" in name:
                new_bundle = name.split("_")[0]
            else:
                new_bundle = name.split(".")[0]
            missing_bundles.append(new_bundle)
        found = False
    return list(set(missing_bundles))

bundles.extend(find_all_missing_lines(data))




def add_bundle(row, bundles = bundles):
    """Hyperspectral Images can be bundled due to different factors
    
    1) year_location_altitude
    2) date
    3) Line
    
    Fortunatly bundles can easily selected via DEMs
    """
    
    if "assays/FLUO" in row["arc_mapping"] or "assay/DEMs" in row["arc_mapping"] or "runs/" in row["arc_mapping"]:
        for bundle in bundles:
            if bundle in row["file_name"]:
                return bundle
            
def add_FLOX_bundles(row):
    pass
        
    


def sort_study(row):
    studies = ["2018_SEL", "2019_WST","2019_NRS","2019_SEL","2019_TR32","2020_CKA","2021_CKA","2021_HOE","2021_GLO","2022_HOE","2022_CKA","2022_INN","2022_SEL","2023_JIM"]
    for study in studies:
        if study in row["arc_mapping"]:
            return study
    return ""

# print(make_description(data.iloc[0,:]))

# %%
# Out:
# []

# %%
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3748 entries, 0 to 3747
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            3748 non-null   object
#  1   last_mod       3748 non-null   object
#  2   size           3748 non-null   float64
#  3   unit           3748 non-null   object
#  4   size_in_bytes  3748 non-null   float64
#  5   desc           0 non-null      float64
#  6   file_name      3748 non-null   object
#  7   file_format    3748 non-null   object
#  8   folder         3747 non-null   object
#  9   arc_mapping    3748 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 292.9+ KB

# %%
def extend_description(row):
    """on new datarame in order to add information"""
    pass



miafpe_df = pd.DataFrame(columns=["Study Unique ID", "Data file link", "Data file description", "Data file version", "ARC label", "Alternative link", "Provenance"])
miafpe_df["Study Unique ID"] = data.apply(sort_study, axis=1)
miafpe_df["Data file link"] = data["url"]
miafpe_df["Data file version"] = 1.0
miafpe_df["ARC label"] = data["arc_mapping"]
miafpe_df["Provenance"] = data.apply(make_provenance, axis=1)
miafpe_df["Data file description"] = data.apply(make_description, axis=1)
miafpe_df["Bundle ID"] = data.apply(add_bundle, axis=1)
# miafpe_df.to_csv("data/MIAFPEDataFiles.csv")

# %%
data["Bundle ID"] = data.apply(add_bundle, axis=1)
data[data["file_format"] == "shp"]
# Out:
#                                                     url          last_mod  \
# 1743  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1748  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1753  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1758  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1763  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1768  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1773  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1778  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1783  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1788  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1793  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# 1798  https://datapub.fz-juelich.de/plantsciences/Hy...  2024-05-08 09:43
# ...

# %%
# all studies
# 2018_SEL, 2019_WST, 2019_NRS, 2019_SEL, 2019_TR32, 2020_CKA, 2021_CKA, 2021_HOE, 2021_GLO, 2022_HOE, 2022_CKA, 2022_INN, 2022_SEL, 2023_JIM

# all studies with FLOX
# 2018_SEL, 2019_WST, 2019_NRS,  2020_CKA, 2021_CKA, 2021_GLO, 2022_CKA
